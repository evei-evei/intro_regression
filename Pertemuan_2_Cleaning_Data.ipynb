# %%
import pandas as pd

# %%
data = pd.read_csv('/content/unclean_data.csv',encoding='latin')

# %%
data.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
data.describe()
# Out:
#        num_critic_for_reviews    duration  actor_3_facebook_likes  \
# count               14.000000   11.000000               14.000000
# mean               506.142857  150.727273             5866.142857
# std                169.069789   21.679903             8289.592695
# min                302.000000  106.000000              161.000000
# 25%                379.250000  141.000000              611.250000
# 50%                448.000000  151.000000             1000.000000
# 75%                635.000000  162.500000             8500.000000
# max                813.000000  183.000000            23000.000000
#
#        ACTOR_1_facebook_likes         gross  num_voted_users  \
# count               14.000000  1.400000e+01     1.300000e+01
# mean             18206.428571  3.335836e+08     4.621578e+05
# std              13905.214361  1.720674e+08     2.687059e+05
# min                451.000000  7.305868e+07     2.122040e+05
# 25%               3500.000000  2.002574e+08     2.948100e+05
# ...

# %%
data.shape
# Out:
# (14, 16)

# %%
data
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
X = 'kampus?'
X = X.replace('?','')
X
# Out:
# 'kampus'

# %%
data['movie_title'] = data ['movie_title'].str.replace('?','')
data
# Out:
#                                     movie_title  num_critic_for_reviews  \
# 0                                       Avatarÿ                     723
# 1     Pirates of the Caribbean: At World's Endÿ                     302
# 2                                      Spectreÿ                     602
# 3                        The Dark Knight Risesÿ                     813
# 4                                  John Carterÿ                     462
# 5                                 Spider-Man 3ÿ                     392
# 6                                      Tangledÿ                     324
# 7                      Avengers: Age of Ultronÿ                     635
# 8                      Avengers: Age of Ultronÿ                     635
# 9       Harry Potter and the Half-Blood Princeÿ                     375
# 10          Batman v Superman: Dawn of Justiceÿ                     673
# 11                            Superman Returnsÿ                     434
# ...

# %%
data['title_year.1'] = data['title_year'].copy()
data
# Out:
#                                     movie_title  num_critic_for_reviews  \
# 0                                       Avatarÿ                     723
# 1     Pirates of the Caribbean: At World's Endÿ                     302
# 2                                      Spectreÿ                     602
# 3                        The Dark Knight Risesÿ                     813
# 4                                  John Carterÿ                     462
# 5                                 Spider-Man 3ÿ                     392
# 6                                      Tangledÿ                     324
# 7                      Avengers: Age of Ultronÿ                     635
# 8                      Avengers: Age of Ultronÿ                     635
# 9       Harry Potter and the Half-Blood Princeÿ                     375
# 10          Batman v Superman: Dawn of Justiceÿ                     673
# 11                            Superman Returnsÿ                     434
# ...

# %%
data['movie_title'] = data ['movie_title'].str.replace('ÿ','')
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
duration = data['duration'].mean()
data['duration'].fillna(duration, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
data['DIRECTOR_facebook_likes'] = data ['DIRECTOR_facebook_likes'].str.replace('\"','')
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
data['DIRECTOR_facebook_likes'] = pd.to_numeric(data['DIRECTOR_facebook_likes'], errors='coerce')
DIRECTOR_facebook_likes = data['DIRECTOR_facebook_likes'].mean()
data['DIRECTOR_facebook_likes'].fillna(DIRECTOR_facebook_likes, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
data['facenumber_in_poster'] = pd.to_numeric(data['facenumber_in_poster'], errors='coerce')
facenumber_in_poster = data['facenumber_in_poster'].mean()
data['facenumber_in_poster'].fillna(facenumber_in_poster, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
Cast_Total_facebook_likes = data['Cast_Total_facebook_likes'].mean()
data['Cast_Total_facebook_likes'].fillna(Cast_Total_facebook_likes, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
num_voted_users = data['num_voted_users'].mean()
data['num_voted_users'].fillna(num_voted_users, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...

# %%
ACTOR_2_facebook_likes = data['ACTOR_2_facebook_likes'].mean()
data['ACTOR_2_facebook_likes'].fillna(ACTOR_2_facebook_likes, inplace=True)
data
# Out:
#                                    movie_title  num_critic_for_reviews  \
# 0                                       Avatar                     723
# 1     Pirates of the Caribbean: At World's End                     302
# 2                                      Spectre                     602
# 3                        The Dark Knight Rises                     813
# 4                                  John Carter                     462
# 5                                 Spider-Man 3                     392
# 6                                      Tangled                     324
# 7                      Avengers: Age of Ultron                     635
# 8                      Avengers: Age of Ultron                     635
# 9       Harry Potter and the Half-Blood Prince                     375
# 10          Batman v Superman: Dawn of Justice                     673
# 11                            Superman Returns                     434
# ...
